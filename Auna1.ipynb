# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df=pd.read_csv("20200115221241-SurveyExport.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7293b1cc31c2> in <module>
# ----> 1 df=pd.read_csv("20200115221241-SurveyExport.csv")
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#      Response ID                 Time Started               Date Submitted  \
# 0              2  13 January 2020 11:30:59 am  13 January 2020 11:32:50 am
# 1              3  13 January 2020 11:41:39 am  13 January 2020 11:57:55 am
# 2              4  13 January 2020 11:50:24 am  13 January 2020 12:05:07 pm
# 3              5  13 January 2020 12:14:22 pm  13 January 2020 12:19:25 pm
# 4              7  13 January 2020 12:55:29 pm  13 January 2020 12:55:29 pm
# ..           ...                          ...                          ...
# 383          386   15 January 2020 1:00:58 pm   15 January 2020 1:08:36 pm
# 384          387   15 January 2020 1:21:13 pm   15 January 2020 1:26:40 pm
# 385          388   15 January 2020 3:43:28 pm   15 January 2020 3:45:35 pm
# 386          389   15 January 2020 5:33:50 pm   15 January 2020 5:41:08 pm
# 387          390   15 January 2020 9:33:34 pm   15 January 2020 9:46:15 pm
#
#        Status  Contact ID  Legacy Comments  Comments Language  \
# ...

# %%
df.columns
# Out:
# Index(['Response ID', 'Time Started', 'Date Submitted', 'Status', 'Contact ID',
#        'Legacy Comments', 'Comments', 'Language', 'Referer', 'SessionID',
#        'User Agent', 'Tags', 'IP Address', 'Longitude', 'Latitude', 'Country',
#        'City', 'State/Region', 'Postal', 'Introduzca su género:',
#        'Introduzca su edad (solo el número):',
#        'Introduzca su distrito de residencia:',
#        '¿Con qué frecuencia se atiende en establecimientos de salud?',
#        'Cuido de mi salud:Hábitos de salud',
#        'Realizo chequeos preventivos:Hábitos de salud',
#        'Como sano:Hábitos de salud', 'Hago ejercicio:Hábitos de salud',
#        'No fumo:Hábitos de salud', 'No bebo alcohol:Hábitos de salud',
#        '¿Cuál considera que es la principal barrera para el cuidado de la salud?',
#        '¿Por qué?',
#        '¿Qué diría que es lo que más le quita tiempo para cuidar su salud? ',
#        '¿Considera que la salud mental es importante para el bienestar?',
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
df.loc[df['Status']=='Complete']
# Out:
#      Response ID                 Time Started               Date Submitted  \
# 0              2  13 January 2020 11:30:59 am  13 January 2020 11:32:50 am
# 1              3  13 January 2020 11:41:39 am  13 January 2020 11:57:55 am
# 2              4  13 January 2020 11:50:24 am  13 January 2020 12:05:07 pm
# 3              5  13 January 2020 12:14:22 pm  13 January 2020 12:19:25 pm
# 7             10   13 January 2020 4:59:55 pm   13 January 2020 5:02:40 pm
# ..           ...                          ...                          ...
# 382          385  15 January 2020 12:52:37 pm   15 January 2020 1:00:01 pm
# 383          386   15 January 2020 1:00:58 pm   15 January 2020 1:08:36 pm
# 384          387   15 January 2020 1:21:13 pm   15 January 2020 1:26:40 pm
# 386          389   15 January 2020 5:33:50 pm   15 January 2020 5:41:08 pm
# 387          390   15 January 2020 9:33:34 pm   15 January 2020 9:46:15 pm
#
#        Status  Contact ID  Legacy Comments  Comments Language  \
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
features = {'Response ID', 'Time Started', 'Date Submitted', 'Status', 'Contact ID',
       'Legacy Comments', 'Comments', 'Language', 'Referer', 'SessionID',
       'User Agent', 'Tags', 'IP Address', 'Longitude', 'Latitude', 'Country',
       'City', 'State/Region', 'Postal', 'Introduzca su género:',
       'Introduzca su edad (solo el número):',
       'Introduzca su distrito de residencia:',
       '¿Con qué frecuencia se atiende en establecimientos de salud?',
       'Cuido de mi salud:Hábitos de salud',
       'Realizo chequeos preventivos:Hábitos de salud',
       'Como sano:Hábitos de salud', 'Hago ejercicio:Hábitos de salud',
       'No fumo:Hábitos de salud', 'No bebo alcohol:Hábitos de salud',
       '¿Cuál considera que es la principal barrera para el cuidado de la salud?',
       '¿Por qué?',
       '¿Qué diría que es lo que más le quita tiempo para cuidar su salud? ',
       '¿Considera que la salud mental es importante para el bienestar?',
       '¿Qué piensa de la medicina alternativa? (ejem. Medicina china, herbolaria, chamanismo, yoga, mindfullness, acupuntura, homeopatía, reiki, shiatzu, etc.)',
       'Si la ha probado, ¿por qué lo hizo? (Si no lo ha hecho, escriba "no la he probado")',
       '¿Le gustaría que su centro de salud la incluya como parte de sus servicios?',
       '¿Qué palabras se le vienen a la mente cuando piensa en "prevención"?',
       'Tengo una buena relación con mis médicos:Relación paciente médico',
       'Me siento en confianza con mis médicos:Relación paciente médico',
       'Puedo hablar con mis médicos sin restricciones:Relación paciente médico',
       'Los médicos se toman el tiempo para explicarme mi dolencia y posibles tratamientos:Relación paciente médico',
       'Los médicos se preocupan porque tenga una vida saludable y hábitos preventivos en salud:Relación paciente médico',
       '¿Tiene médicos de su preferencia?', '¿Por qué?.1', 'New Radio Buttons',
       '¿Cuál es su principal fuente de información médica?',
       '¿Por qué acude a la fuente anteriormente mencionada?',
       '¿Considera necesario un contacto continuo con su centro de salud?',
       'Whatsapp:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)',
       'Redes sociales:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)',
       'App:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)',
       'Llamadas telefónicas:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)',
       'Medios físicos:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)',
       'No deseo ser contactado:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)',
       '¿Cuándo le gustaría ser contactado?',
       'Introduzca su correo para fines de sorteo:'}

# %%
type(features)
# Out:
# set

# %%
str = 'fg'

res= {element: 'F'+str for element in features}

# %%
res
# Out:
# {'City': 'Ffg',
#  'Country': 'Ffg',
#  'New Radio Buttons': 'Ffg',
#  '¿Qué palabras se le vienen a la mente cuando piensa en "prevención"?': 'Ffg',
#  'Introduzca su correo para fines de sorteo:': 'Ffg',
#  '¿Qué piensa de la medicina alternativa? (ejem. Medicina china, herbolaria, chamanismo, yoga, mindfullness, acupuntura, homeopatía, reiki, shiatzu, etc.)': 'Ffg',
#  'Llamadas telefónicas:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)': 'Ffg',
#  'Latitude': 'Ffg',
#  'IP Address': 'Ffg',
#  'Status': 'Ffg',
#  'State/Region': 'Ffg',
#  'Como sano:Hábitos de salud': 'Ffg',
#  'Postal': 'Ffg',
#  'Comments': 'Ffg',
#  'SessionID': 'Ffg',
#  'Introduzca su edad (solo el número):': 'Ffg',
#  'Cuido de mi salud:Hábitos de salud': 'Ffg',
#  'Me siento en confianza con mis médicos:Relación paciente médico': 'Ffg',
#  'Los médicos se preocupan porque tenga una vida saludable y hábitos preventivos en salud:Relación paciente médico': 'Ffg',
# ...

# %%
type(features)
# Out:
# set

# %%
res = dict.fromkeys(features,0)

# %%
res
# Out:
# {'City': 0,
#  'Country': 0,
#  'New Radio Buttons': 0,
#  '¿Qué palabras se le vienen a la mente cuando piensa en "prevención"?': 0,
#  'Introduzca su correo para fines de sorteo:': 0,
#  '¿Qué piensa de la medicina alternativa? (ejem. Medicina china, herbolaria, chamanismo, yoga, mindfullness, acupuntura, homeopatía, reiki, shiatzu, etc.)': 0,
#  'Llamadas telefónicas:¿A través de qué herramientas le gustaría ser contactado? (Puede marcar más de una opción)': 0,
#  'Latitude': 0,
#  'IP Address': 0,
#  'Status': 0,
#  'State/Region': 0,
#  'Como sano:Hábitos de salud': 0,
#  'Postal': 0,
#  'Comments': 0,
#  'SessionID': 0,
#  'Introduzca su edad (solo el número):': 0,
#  'Cuido de mi salud:Hábitos de salud': 0,
#  'Me siento en confianza con mis médicos:Relación paciente médico': 0,
#  'Los médicos se preocupan porque tenga una vida saludable y hábitos preventivos en salud:Relación paciente médico': 0,
#  'Referer': 0,
#  '¿Cuál es su principal fuente de información médica?': 0,
# ...

# %%
import seaborn as sns
sns.boxplot(x='Introduzca su edad (solo el número):', data=df)

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df['Introduzca su edad (solo el número):']))
print(z)
# Out:
# [2.00166454e-01 2.00166454e-01 2.00166454e-01 2.37422037e-01
#  1.96091591e+01 1.78877550e-01 1.78877550e-01 2.00166454e-01
#  2.16133133e-01 2.21455359e-01 1.89522002e-01 2.21455359e-01
#  2.05488681e-01 2.00166454e-01 2.16133133e-01 2.05488681e-01
#  2.05488681e-01 2.05488681e-01 2.16133133e-01 2.05488681e-01
#  6.71108020e-02 1.84199776e-01 1.57588646e-01 2.05488681e-01
#  1.68233098e-01 9.90441586e-02 1.78877550e-01 1.78877550e-01
#  7.40036335e-03 1.78877550e-01 1.46944193e-01 1.57588646e-01
#  1.38885410e-02 1.41621967e-01 1.94844228e-01 6.17885759e-02
#  1.15010837e-01 1.57588646e-01 2.98552193e-02 2.21455359e-01
#  1.78877550e-01 2.00166454e-01 1.89522002e-01 1.25655289e-01
#  1.25655289e-01 1.30977515e-01 2.37422037e-01 1.52266420e-01
#  1.94844228e-01 4.58218976e-02 3.51774454e-02 1.78877550e-01
#  3.51774454e-02 1.15010837e-01 1.27225894e-02 2.45329932e-02
#  1.38885410e-02 1.27225894e-02 2.07813725e-03 8.56631494e-03
# ...

# %%
threshold = 3
print(np.where(z > 3))
# Out:
# (array([4], dtype=int64),)

# %%
z[4]
# Out:
# 19.60915908215983

# %%
df_o= df
df.shape
# Out:
# (388, 56)

# %%
z.shape
# Out:
# (388,)

# %%
df_o = df_o[(z<3)]

# %%
df.shape
# Out:
# (388, 56)

# %%
df_o.shape
# Out:
# (387, 56)

# %%
df_o1=df

# %%
Q1=df_o1.quantile(0.25)
Q3=df_o1.quantile(0.75)
IQR=Q3-Q1

df_out=df_o1[~((df_o1 < (Q1 - 1.5 * IQR)) |(df_o1 > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df_out.shape
# Out:
# (334, 56)

# %%
df_out
# Out:
#      Response ID                 Time Started               Date Submitted  \
# 0              2  13 January 2020 11:30:59 am  13 January 2020 11:32:50 am
# 1              3  13 January 2020 11:41:39 am  13 January 2020 11:57:55 am
# 2              4  13 January 2020 11:50:24 am  13 January 2020 12:05:07 pm
# 3              5  13 January 2020 12:14:22 pm  13 January 2020 12:19:25 pm
# 5              8   13 January 2020 1:04:47 pm   13 January 2020 1:04:47 pm
# ..           ...                          ...                          ...
# 380          383   15 January 2020 9:35:42 am   15 January 2020 9:39:56 am
# 381          384  15 January 2020 10:14:39 am  15 January 2020 10:21:09 am
# 382          385  15 January 2020 12:52:37 pm   15 January 2020 1:00:01 pm
# 385          388   15 January 2020 3:43:28 pm   15 January 2020 3:45:35 pm
# 387          390   15 January 2020 9:33:34 pm   15 January 2020 9:46:15 pm
#
#        Status  Contact ID  Legacy Comments  Comments Language  \
# ...

# %%
import seaborn as sns
sns.boxplot(x='Introduzca su edad (solo el número):', data=df_out)

# %% [markdown]
# ## con qué frecuencia te atiendes -> cada vez que me enfermo, hacer match con Hábitos de Salud

# %% [markdown]
# df['']

# %%
]}
